# %%
# %load_ext autoreload
# %autoreload 2

# %%
import septum_mec.analysis.data_processing as dp
# Out:
# 13:42:35 [I] klustakwik KlustaKwik2 version 0.2.6
# /home/mikkel/.virtualenvs/expipe/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/mikkel/.virtualenvs/expipe/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
# action_id = '1834-110319-6'
action_id = '1833-200619-4'

# %%
data = dp.Data(position_sampling_rate=100, position_low_pass_frequency=10, box_size=[1, 1])
x, y, t, v = map(data.tracking(action_id).get, ['x', 'y', 't', 'v'])
# Out:
# /media/storage/expipe/septum-mec/actions/1833-200619-4/data/main.exdir/processing/tracking/camera_0/Position/led_0/data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
y
# Out:
# array([0.11296338, 0.11363233, 0.11429071, ..., 0.49965473, 0.49958819,
#        0.49953992])

# %%
a = data.lfp(action_id, 0)

# %%
plt.plot(a)
plt.xlim(0,10000)
plt.ylim(-10, 10)
# Out:
# (-10, 10)

# %%
'd80d009f2b76f2b3063bb3793f2ee685' == '5f170b4976e6b96d9204ffee639442b4'
# Out:
# False
